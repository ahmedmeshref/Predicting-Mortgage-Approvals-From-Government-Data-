# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing 
from sklearn.model_selection import train_test_split
from catboost import CatBoostClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
# %matplotlib inline

# %%
# Loading the datasets
df = pd.read_csv("train_values.csv")
df_tar= pd.read_csv("train_labels.csv")

# %%
df.head(5)
# Out:
#    row_id  loan_type  property_type  loan_purpose  occupancy  loan_amount  \
# 0       0          3              1             1          1         70.0
# 1       1          1              1             3          1        178.0
# 2       2          2              1             3          1        163.0
# 3       3          1              1             1          1        155.0
# 4       4          1              1             1          1        305.0
#
#    preapproval  msa_md  state_code  county_code  ...  applicant_sex  \
# 0            3      18          37          246  ...              1
# 1            3     369          52          299  ...              1
# 2            3      16          10          306  ...              1
# 3            1     305          47          180  ...              1
# 4            3      24          37           20  ...              2
#
#    applicant_income  population  minority_population_pct  \
# 0              24.0      6203.0                   44.230
# 1              57.0      5774.0                   15.905
# 2              67.0      6094.0                   61.270
# 3             105.0      6667.0                    6.246
# 4              71.0      6732.0                  100.000
#
#    ffiecmedian_family_income  tract_to_msa_md_income_pct  \
# 0                    60588.0                      50.933
# 1                    54821.0                     100.000
# 2                    67719.0                     100.000
# 3                    78439.0                     100.000
# 4                    63075.0                      82.200
#
#    number_of_owner-occupied_units  number_of_1_to_4_family_units  lender  \
# 0                           716.0                         2642.0    4536
# 1                          1622.0                         2108.0    2458
# 2                           760.0                         1048.0    5710
# 3                          2025.0                         2299.0    5888
# 4                          1464.0                         1847.0     289
#
#    co_applicant
# 0         False
# 1         False
# 2         False
# 3          True
# 4         False
#
# [5 rows x 22 columns]

# %%
df.describe()
# Out:
#               row_id      loan_type  property_type   loan_purpose  \
# count  500000.000000  500000.000000  500000.000000  500000.000000
# mean   249999.500000       1.366276       1.047650       2.066810
# std    144337.711634       0.690555       0.231404       0.948371
# min         0.000000       1.000000       1.000000       1.000000
# 25%    124999.750000       1.000000       1.000000       1.000000
# 50%    249999.500000       1.000000       1.000000       2.000000
# 75%    374999.250000       2.000000       1.000000       3.000000
# max    499999.000000       4.000000       3.000000       3.000000
#
#            occupancy    loan_amount    preapproval         msa_md  \
# count  500000.000000  500000.000000  500000.000000  500000.000000
# mean        1.109590     221.753158       2.764722     181.606972
# std         0.326092     590.641648       0.543061     138.464169
# min         1.000000       1.000000       1.000000      -1.000000
# 25%         1.000000      93.000000       3.000000      25.000000
# 50%         1.000000     162.000000       3.000000     192.000000
# 75%         1.000000     266.000000       3.000000     314.000000
# max         3.000000  100878.000000       3.000000     408.000000
#
#           state_code    county_code  ...  applicant_race  applicant_sex  \
# count  500000.000000  500000.000000  ...   500000.000000  500000.000000
# mean       23.726924     144.542062  ...        4.786586       1.462374
# std        15.982768     100.243612  ...        1.024927       0.677685
# min        -1.000000      -1.000000  ...        1.000000       1.000000
# 25%         6.000000      57.000000  ...        5.000000       1.000000
# 50%        26.000000     131.000000  ...        5.000000       1.000000
# 75%        37.000000     246.000000  ...        5.000000       2.000000
# max        52.000000     324.000000  ...        7.000000       4.000000
#
#        applicant_income     population  minority_population_pct  \
# count     460052.000000  477535.000000            477534.000000
# mean         102.389521    5416.833956                31.617310
# std          153.534496    2728.144999                26.333938
# min            1.000000      14.000000                 0.534000
# 25%           47.000000    3744.000000                10.700000
# 50%           74.000000    4975.000000                22.901000
# 75%          117.000000    6467.000000                46.020000
# max        10139.000000   37097.000000               100.000000
#
#        ffiecmedian_family_income  tract_to_msa_md_income_pct  \
# count              477560.000000               477486.000000
# mean                69235.603298                   91.832624
# std                 14810.058791                   14.210924
# min                 17858.000000                    3.981000
# 25%                 59731.000000                   88.067250
# 50%                 67526.000000                  100.000000
# 75%                 75351.000000                  100.000000
# max                125248.000000                  100.000000
#
#        number_of_owner-occupied_units  number_of_1_to_4_family_units  \
# count                   477435.000000                  477470.000000
# mean                      1427.718282                    1886.147065
# std                        737.559511                     914.123744
# min                          4.000000                       1.000000
# 25%                        944.000000                    1301.000000
# 50%                       1327.000000                    1753.000000
# 75%                       1780.000000                    2309.000000
# max                       8771.000000                   13623.000000
#
#               lender
# count  500000.000000
# mean     3720.121344
# std      1838.313175
# min         0.000000
# 25%      2442.000000
# 50%      3731.000000
# 75%      5436.000000
# max      6508.000000
#
# [8 rows x 21 columns]

# %%
# droping the row_id column
df.drop("row_id", axis = 1, inplace =True)

# %%
# replacing any -1 values with np.nan to deal with it as missing values 
for i in df.columns:
    df[i] = df[i].replace(-1, np.nan)

df.isnull().sum()
# Out:
# loan_type                             0
# property_type                         0
# loan_purpose                          0
# occupancy                             0
# loan_amount                           0
# preapproval                           0
# msa_md                            76982
# state_code                        19132
# county_code                       20466
# applicant_ethnicity                   0
# applicant_race                        0
# applicant_sex                         0
# applicant_income                  39948
# population                        22465
# minority_population_pct           22466
# ffiecmedian_family_income         22440
# tract_to_msa_md_income_pct        22514
# number_of_owner-occupied_units    22565
# number_of_1_to_4_family_units     22530
# lender                                0
# co_applicant                          0
# dtype: int64

# %%
# replacing the boolean values in the co-applicant columns to 0 and 1 integers
le = preprocessing.LabelEncoder()
df["co_applicant"]=le.fit_transform(df["co_applicant"])
df["co_applicant"].unique()
# Out:
# array([0, 1])

# %%
# replacing the missing values in the categorical columns with 0    
df["msa_md"] = df["msa_md"].fillna(0)
df["state_code"] = df["state_code"].fillna(0)
df["county_code"] = df["county_code"].fillna(0)

# %%
df.isnull().sum()
# Out:
# loan_type                             0
# property_type                         0
# loan_purpose                          0
# occupancy                             0
# loan_amount                           0
# preapproval                           0
# msa_md                                0
# state_code                            0
# county_code                           0
# applicant_ethnicity                   0
# applicant_race                        0
# applicant_sex                         0
# applicant_income                  39948
# population                        22465
# minority_population_pct           22466
# ffiecmedian_family_income         22440
# tract_to_msa_md_income_pct        22514
# number_of_owner-occupied_units    22565
# number_of_1_to_4_family_units     22530
# lender                                0
# co_applicant                          0
# dtype: int64

# %%
# replacing the numrical columns with the median
df["population"].fillna(df["population"].median(), inplace = True)

df["minority_population_pct"].fillna(df["minority_population_pct"].median(), inplace = True)

df["ffiecmedian_family_income"].fillna(df["ffiecmedian_family_income"].median(), 
                                       inplace = True)

df["number_of_owner-occupied_units"].fillna(df["number_of_owner-occupied_units"].median(), 
                                            inplace = True)

df["tract_to_msa_md_income_pct"].fillna(df["tract_to_msa_md_income_pct"].median(), 
                                        inplace = True)

df["number_of_1_to_4_family_units"].fillna(df["number_of_1_to_4_family_units"].median(),
                                           inplace = True)

# %%
# Getting the log of the loan amount column to deal with the outliers
df['loan_amount'] = np.log(df['loan_amount'])

# %%
# ploting the logged loan amount column
sns.distplot(df['loan_amount'], bins = 10)
plt.xlabel("log loan amount")
plt.ylabel("frequency")
plt.title("distribution of the logged loan amount")
plt.box(False)
plt.grid(color = "white")
plt.show()

# %%
# filling the missing values in the applicant income column and getting logged values to treat the outliers
df["applicant_income"].fillna(df["applicant_income"].median(), inplace = True)
df['applicant_income'] = np.log(df['applicant_income'])

# %%
# visualizing the new logged applicant income 
sns.distplot(df['applicant_income'], bins = 10)
plt.xlabel("log applicant income")
plt.ylabel("frequency")
plt.title("distribution of the logged applicant income")
plt.box(False)
plt.grid(color = "white")
plt.show()

# %%
df.head(5).T
# Out:
#                                            0             1             2  \
# loan_type                           3.000000      1.000000      2.000000
# property_type                       1.000000      1.000000      1.000000
# loan_purpose                        1.000000      3.000000      3.000000
# occupancy                           1.000000      1.000000      1.000000
# loan_amount                         4.248495      5.181784      5.093750
# preapproval                         3.000000      3.000000      3.000000
# msa_md                             18.000000    369.000000     16.000000
# state_code                         37.000000     52.000000     10.000000
# county_code                       246.000000    299.000000    306.000000
# applicant_ethnicity                 2.000000      1.000000      2.000000
# applicant_race                      5.000000      5.000000      5.000000
# applicant_sex                       1.000000      1.000000      1.000000
# applicant_income                    3.178054      4.043051      4.204693
# population                       6203.000000   5774.000000   6094.000000
# minority_population_pct            44.230000     15.905000     61.270000
# ffiecmedian_family_income       60588.000000  54821.000000  67719.000000
# tract_to_msa_md_income_pct         50.933000    100.000000    100.000000
# number_of_owner-occupied_units    716.000000   1622.000000    760.000000
# number_of_1_to_4_family_units    2642.000000   2108.000000   1048.000000
# lender                           4536.000000   2458.000000   5710.000000
# co_applicant                        0.000000      0.000000      0.000000
#
#                                            3             4
# loan_type                           1.000000      1.000000
# property_type                       1.000000      1.000000
# loan_purpose                        1.000000      1.000000
# occupancy                           1.000000      1.000000
# loan_amount                         5.043425      5.720312
# preapproval                         1.000000      3.000000
# msa_md                            305.000000     24.000000
# state_code                         47.000000     37.000000
# county_code                       180.000000     20.000000
# applicant_ethnicity                 2.000000      2.000000
# applicant_race                      5.000000      3.000000
# applicant_sex                       1.000000      2.000000
# applicant_income                    4.653960      4.262680
# population                       6667.000000   6732.000000
# minority_population_pct             6.246000    100.000000
# ffiecmedian_family_income       78439.000000  63075.000000
# tract_to_msa_md_income_pct        100.000000     82.200000
# number_of_owner-occupied_units   2025.000000   1464.000000
# number_of_1_to_4_family_units    2299.000000   1847.000000
# lender                           5888.000000    289.000000
# co_applicant                        1.000000      0.000000

# %%
# getting a better sense of the corrlation between the different features and the target column 
df.apply(lambda x: x.corr(df_tar.accepted))
# Out:
# loan_type                         0.018589
# property_type                    -0.080603
# loan_purpose                     -0.131595
# occupancy                         0.022043
# loan_amount                       0.169416
# preapproval                       0.017209
# msa_md                            0.080046
# state_code                        0.088597
# county_code                       0.052264
# applicant_ethnicity               0.009777
# applicant_race                    0.045361
# applicant_sex                    -0.038391
# applicant_income                  0.178756
# population                        0.025540
# minority_population_pct          -0.076546
# ffiecmedian_family_income         0.070197
# tract_to_msa_md_income_pct        0.064809
# number_of_owner-occupied_units    0.040934
# number_of_1_to_4_family_units     0.012038
# lender                            0.008494
# co_applicant                      0.101116
# dtype: float64

# %%
# getting a better sense of the corrlation between the columns and each others
df.corr()
# Out:
#                                 loan_type  property_type  loan_purpose  \
# loan_type                        1.000000      -0.065214     -0.121296
# property_type                   -0.065214       1.000000     -0.114663
# loan_purpose                    -0.121296      -0.114663      1.000000
# occupancy                       -0.158964       0.156139      0.002154
# loan_amount                      0.096810      -0.092098      0.021272
# preapproval                     -0.133156       0.046035      0.487352
# msa_md                          -0.024350      -0.075847      0.072274
# state_code                      -0.046627      -0.017681      0.116167
# county_code                     -0.016259      -0.007411      0.057763
# applicant_ethnicity             -0.050118       0.131192      0.023305
# applicant_race                  -0.016649       0.063428      0.021642
# applicant_sex                   -0.072372       0.106785      0.014322
# applicant_income                -0.135373      -0.133746      0.037029
# population                       0.040495      -0.028243     -0.005286
# minority_population_pct          0.012583      -0.019480      0.056949
# ffiecmedian_family_income       -0.069101      -0.089631      0.060785
# tract_to_msa_md_income_pct      -0.002291      -0.053266     -0.022783
# number_of_owner-occupied_units   0.033843      -0.029751     -0.009738
# number_of_1_to_4_family_units    0.050889       0.003194     -0.016767
# lender                          -0.027408      -0.035769      0.051664
# co_applicant                    -0.025502      -0.029625      0.013419
#
#                                 occupancy  loan_amount  preapproval    msa_md  \
# loan_type                       -0.158964     0.096810    -0.133156 -0.024350
# property_type                    0.156139    -0.092098     0.046035 -0.075847
# loan_purpose                     0.002154     0.021272     0.487352  0.072274
# occupancy                        1.000000     0.006548     0.043719 -0.012269
# loan_amount                      0.006548     1.000000    -0.084002  0.069441
# preapproval                      0.043719    -0.084002     1.000000  0.130022
# msa_md                          -0.012269     0.069441     0.130022  1.000000
# state_code                       0.011175     0.096504     0.178322  0.143800
# county_code                      0.008095    -0.007240     0.157662  0.159649
# applicant_ethnicity              0.159449     0.058661     0.016996 -0.011815
# applicant_race                   0.066717     0.006409     0.018578 -0.025158
# applicant_sex                    0.132245    -0.050456     0.019185  0.004969
# applicant_income                 0.135599     0.473655     0.020631  0.075686
# population                      -0.051035     0.052439     0.002174  0.072105
# minority_population_pct          0.049574    -0.025696     0.064595  0.097610
# ffiecmedian_family_income       -0.024807     0.270848     0.017152  0.263391
# tract_to_msa_md_income_pct      -0.101758     0.192670    -0.075085 -0.055407
# number_of_owner-occupied_units  -0.087846     0.039886    -0.006440  0.047922
# number_of_1_to_4_family_units   -0.019253    -0.026319     0.001400 -0.030940
# lender                          -0.001298     0.042993     0.000559  0.013482
# co_applicant                    -0.016899     0.149988     0.013920 -0.004502
#
#                                 state_code  county_code  applicant_ethnicity  \
# loan_type                        -0.046627    -0.016259            -0.050118
# property_type                    -0.017681    -0.007411             0.131192
# loan_purpose                      0.116167     0.057763             0.023305
# occupancy                         0.011175     0.008095             0.159449
# loan_amount                       0.096504    -0.007240             0.058661
# preapproval                       0.178322     0.157662             0.016996
# msa_md                            0.143800     0.159649            -0.011815
# state_code                        1.000000     0.016186            -0.001454
# county_code                       0.016186     1.000000             0.005655
# applicant_ethnicity              -0.001454     0.005655             1.000000
# applicant_race                    0.004160    -0.003588             0.280871
# applicant_sex                    -0.001747    -0.000465             0.497732
# applicant_income                  0.059770     0.019682             0.072210
# population                       -0.076633     0.076927            -0.038283
# minority_population_pct           0.033018     0.036641            -0.172978
# ffiecmedian_family_income         0.197729     0.053440             0.080283
# tract_to_msa_md_income_pct       -0.059256    -0.047254             0.042581
# number_of_owner-occupied_units   -0.099084     0.055712             0.010559
# number_of_1_to_4_family_units    -0.119953     0.059162             0.004021
# lender                            0.020445     0.002760             0.009411
# co_applicant                      0.029680     0.003698            -0.124085
#
#                                 ...  applicant_sex  applicant_income  \
# loan_type                       ...      -0.072372         -0.135373
# property_type                   ...       0.106785         -0.133746
# loan_purpose                    ...       0.014322          0.037029
# occupancy                       ...       0.132245          0.135599
# loan_amount                     ...      -0.050456          0.473655
# preapproval                     ...       0.019185          0.020631
# msa_md                          ...       0.004969          0.075686
# state_code                      ...      -0.001747          0.059770
# county_code                     ...      -0.000465          0.019682
# applicant_ethnicity             ...       0.497732          0.072210
# applicant_race                  ...       0.266636          0.016031
# applicant_sex                   ...       1.000000         -0.090560
# applicant_income                ...      -0.090560          1.000000
# population                      ...      -0.022596          0.030431
# minority_population_pct         ...       0.053742         -0.081347
# ffiecmedian_family_income       ...       0.017997          0.225263
# tract_to_msa_md_income_pct      ...      -0.057335          0.187356
# number_of_owner-occupied_units  ...      -0.038815          0.046696
# number_of_1_to_4_family_units   ...      -0.031758         -0.014989
# lender                          ...       0.016742          0.017967
# co_applicant                    ...      -0.294779          0.275921
#
#                                 population  minority_population_pct  \
# loan_type                         0.040495                 0.012583
# property_type                    -0.028243                -0.019480
# loan_purpose                     -0.005286                 0.056949
# occupancy                        -0.051035                 0.049574
# loan_amount                       0.052439                -0.025696
# preapproval                       0.002174                 0.064595
# msa_md                            0.072105                 0.097610
# state_code                       -0.076633                 0.033018
# county_code                       0.076927                 0.036641
# applicant_ethnicity              -0.038283                -0.172978
# applicant_race                   -0.033176                -0.223815
# applicant_sex                    -0.022596                 0.053742
# applicant_income                  0.030431                -0.081347
# population                        1.000000                 0.089520
# minority_population_pct           0.089520                 1.000000
# ffiecmedian_family_income        -0.013525                 0.022714
# tract_to_msa_md_income_pct        0.144223                -0.446851
# number_of_owner-occupied_units    0.858751                -0.211745
# number_of_1_to_4_family_units     0.817066                -0.155352
# lender                            0.001575                 0.010792
# co_applicant                      0.015906                -0.100620
#
#                                 ffiecmedian_family_income  \
# loan_type                                       -0.069101
# property_type                                   -0.089631
# loan_purpose                                     0.060785
# occupancy                                       -0.024807
# loan_amount                                      0.270848
# preapproval                                      0.017152
# msa_md                                           0.263391
# state_code                                       0.197729
# county_code                                      0.053440
# applicant_ethnicity                              0.080283
# applicant_race                                  -0.077019
# applicant_sex                                    0.017997
# applicant_income                                 0.225263
# population                                      -0.013525
# minority_population_pct                          0.022714
# ffiecmedian_family_income                        1.000000
# tract_to_msa_md_income_pct                      -0.057068
# number_of_owner-occupied_units                  -0.020667
# number_of_1_to_4_family_units                   -0.147338
# lender                                           0.021496
# co_applicant                                     0.018252
#
#                                 tract_to_msa_md_income_pct  \
# loan_type                                        -0.002291
# property_type                                    -0.053266
# loan_purpose                                     -0.022783
# occupancy                                        -0.101758
# loan_amount                                       0.192670
# preapproval                                      -0.075085
# msa_md                                           -0.055407
# state_code                                       -0.059256
# county_code                                      -0.047254
# applicant_ethnicity                               0.042581
# applicant_race                                    0.058163
# applicant_sex                                    -0.057335
# applicant_income                                  0.187356
# population                                        0.144223
# minority_population_pct                          -0.446851
# ffiecmedian_family_income                        -0.057068
# tract_to_msa_md_income_pct                        1.000000
# number_of_owner-occupied_units                    0.354143
# number_of_1_to_4_family_units                     0.205098
# lender                                            0.004853
# co_applicant                                      0.098489
#
#                                 number_of_owner-occupied_units  \
# loan_type                                             0.033843
# property_type                                        -0.029751
# loan_purpose                                         -0.009738
# occupancy                                            -0.087846
# loan_amount                                           0.039886
# preapproval                                          -0.006440
# msa_md                                                0.047922
# state_code                                           -0.099084
# county_code                                           0.055712
# applicant_ethnicity                                   0.010559
# applicant_race                                        0.018085
# applicant_sex                                        -0.038815
# applicant_income                                      0.046696
# population                                            0.858751
# minority_population_pct                              -0.211745
# ffiecmedian_family_income                            -0.020667
# tract_to_msa_md_income_pct                            0.354143
# number_of_owner-occupied_units                        1.000000
# number_of_1_to_4_family_units                         0.887399
# lender                                               -0.002071
# co_applicant                                          0.043513
#
#                                 number_of_1_to_4_family_units    lender  \
# loan_type                                            0.050889 -0.027408
# property_type                                        0.003194 -0.035769
# loan_purpose                                        -0.016767  0.051664
# occupancy                                           -0.019253 -0.001298
# loan_amount                                         -0.026319  0.042993
# preapproval                                          0.001400  0.000559
# msa_md                                              -0.030940  0.013482
# state_code                                          -0.119953  0.020445
# county_code                                          0.059162  0.002760
# applicant_ethnicity                                  0.004021  0.009411
# applicant_race                                       0.027645  0.005197
# applicant_sex                                       -0.031758  0.016742
# applicant_income                                    -0.014989  0.017967
# population                                           0.817066  0.001575
# minority_population_pct                             -0.155352  0.010792
# ffiecmedian_family_income                           -0.147338  0.021496
# tract_to_msa_md_income_pct                           0.205098  0.004853
# number_of_owner-occupied_units                       0.887399 -0.002071
# number_of_1_to_4_family_units                        1.000000 -0.007240
# lender                                              -0.007240  1.000000
# co_applicant                                         0.030970  0.000042
#
#                                 co_applicant
# loan_type                          -0.025502
# property_type                      -0.029625
# loan_purpose                        0.013419
# occupancy                          -0.016899
# loan_amount                         0.149988
# preapproval                         0.013920
# msa_md                             -0.004502
# state_code                          0.029680
# county_code                         0.003698
# applicant_ethnicity                -0.124085
# applicant_race                     -0.025120
# applicant_sex                      -0.294779
# applicant_income                    0.275921
# population                          0.015906
# minority_population_pct            -0.100620
# ffiecmedian_family_income           0.018252
# tract_to_msa_md_income_pct          0.098489
# number_of_owner-occupied_units      0.043513
# number_of_1_to_4_family_units       0.030970
# lender                              0.000042
# co_applicant                        1.000000
#
# [21 rows x 21 columns]

# %%
# plot the corrlation between two columns 
sns.set()
sns.set_context("paper")
sns.lmplot(x ="number_of_1_to_4_family_units", y = "number_of_owner-occupied_units", data=df) 
plt.title("Corrlation between number_of_1_to_4_family_units and number_of_owner-occupied_units")
# Out:
# Text(0.5, 1.0, 'Corrlation between number_of_1_to_4_family_units and number_of_owner-occupied_units')

# %%
# spliting the data
x = df
y = df_tar["accepted"]
x_train,x_test,y_train,y_test = train_test_split(x , y , test_size= 0.2 , random_state=1234)

# %%
# identifying the categorical columns for the model
cat_feat = [0, 1, 2, 3, 5, 6, 7, 8, 9, 10, 11, 19, 20]

# %%
# Building the model
model = CatBoostClassifier(eval_metric='Accuracy', use_best_model=True, random_seed=42, 
                           learning_rate=0.24, silent=True, cat_features=cat_feat, depth = 6)
model.fit(x_train,y_train,eval_set=(x_test,y_test))

# %%
# predicting the test data and evaluating it 
yhat = model.predict(x_test)
print("accuracy of the model=", accuracy_score(y_test, yhat)) 
print("class", classification_report(y_test, yhat))
# Out:
# accuracy of the model= 0.73118
# class               precision    recall  f1-score   support
#
#            0       0.76      0.68      0.72     49811
#            1       0.71      0.78      0.74     50189
#
#    micro avg       0.73      0.73      0.73    100000
#    macro avg       0.73      0.73      0.73    100000
# weighted avg       0.73      0.73      0.73    100000

# %%
# building a confusion matrix for the evaluation and slicing it into four pieces
confusion = confusion_matrix(y_test, yhat)
print(confusion)
#[row, column]
TP = confusion[1, 1]
TN = confusion[0, 0]
FP = confusion[0, 1]
FN = confusion[1, 0]
# Out:
# [[33882 15929]
#  [10953 39236]]
